# %% [markdown]
# # Dimension Reduction comes under USL
# ## We will reduce the dimensions of the dataset w.r.t columns

# %% [markdown]
# ## There are two algorithms which come under Dimensionalty Reduction
# ## They are
# - 1.Principal Component Analysis
# - 2.Singular Value Decomposition

# %% [markdown]
# ### SVD is mainly used in Advanced Analytics

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Python Scripts\PCA\dm.jpg")

# %% [markdown]
# ## Applications of the Dimension Reduction :

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Python Scripts\PCA\dmap.jpg")

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Python Scripts\PCA\ben.jpg")

# %% [markdown]
# ### PCA Key Benefits:

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Python Scripts\PCA\pc.jpg")

# %%
Use 3 columns and use 6 columns
# Out:
#   File "<ipython-input-9-f321c39ec428>", line 1
#     Use 3 columns and use 6 columns
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## PCA Preliminaries:

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Python Scripts\PCA\pl.jpg")

# %% [markdown]
# ## PCA is also called as less transparent algorithm

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Python Scripts\PCA\pw.jpg")

# %% [markdown]
# ## Standardize the variables:

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Python Scripts\PCA\pcw.jpg")

# %% [markdown]
# ## PCs Calculation:

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Python Scripts\PCA\weights.jpg")

# %% [markdown]
# ## PCA Goal 1: Data Reduction

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Python Scripts\PCA\pcweight.jpg")

# %% [markdown]
# ### PCA Goal 2 -  Labeling PCs:

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Python Scripts\PCA\goal.jpg")

# %% [markdown]
# ### PCA Goal3 - PCA for Visualization

# %%
from IPython.display import Image
Image(r"C:\Users\Veerabhadra\Documents\DS\Python Scripts\PCA\vis.jpg")
